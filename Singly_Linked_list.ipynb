# %%
class node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        
class llist:
    def __init__(self):
        self.head = node()
        
    def append_at_end(self,data):
        cur = self.head
        while cur.next != None:
            cur = cur.next
        cur.next = node(data)
       
    def append_at_head(self,data):
        new_node = node(data)
        new_node.next = self.head
        self.head = new_node
        
    def append_at_specific_position(self,data,position):
        new_node = node(data)
        cur = self.head
        self.position = position
        while position > 1:
            cur = cur.next
            position -= 1
        new_node.next = cur.next
        cur.next = new_node
    
    def delete_from_end(self):
        cur = self.head
        while cur.next.next != None:
            cur = cur.next
        cur.next = None
        
    def delete_from_head(self):
        cur = self.head
        cur.next = cur.next.next
        cur = cur.next
      
    def delete_from_specific_pos(self,position):
        self.position = position
        cur = self.head
        while position >1:
            cur = cur.next
            position -= 1
        cur.next = cur.next.next 
        
    def display(self):
        cur = self.head
        while cur.next!= None:
            cur = cur.next
            print(cur.data)
            
    def reverse_list(self):
        prev = None
        cur = self.head.next
        while cur.next != None:
            next = cur.next
            cur.next = prev
            prev = cur
            cur = next
        self.head = prev
        
llist=linked_list()
llist.append_at_end(2)
llist.append_at_end(3)
llist.append_at_end(256)
llist.append_at_end(67)
llist.append_at_end(99)
llist.append_at_end(1)
llist.append_at_end(45)
llist.append_at_head(100)
llist.append_at_head(10)
llist.append_at_specific_position(5,3)
llist.display()
print("delete from end")
llist.delete_from_end()
llist.delete_from_head()
llist.display()
# Out:
# 10
# 100
# 5
# 2
# 3
# 256
# 67
# 99
# 1
# 45
# delete from end
# 100
# 5
# 2
# 3
# 256
# 67
# 99
# 1
